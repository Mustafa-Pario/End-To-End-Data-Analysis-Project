# %%
from data_loading.kaggle_loader import download_data
from extraction.zip_extractor import extract_file
from transformation.data_transformer import transform_data
from database.sql_loader import load_data

# Execute the steps
download_data()
extract_file()
df = transform_data()
load_data(df)
